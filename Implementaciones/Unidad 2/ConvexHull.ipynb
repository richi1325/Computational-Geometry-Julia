# %%
include("../../modules/CovexHull/covexHull.jl")
# Out:
# convexHullGiftWrapping (generic function with 1 method)

# %% [markdown]
# ## Convex Hull Graham Scan

# %%
Points = readPoints("GrahamScan.txt")
# Out:
# 9-element Vector{Point}:
#  Point(7, 6)
#  Point(-2, 5)
#  Point(-1, -1)
#  Point(2, 0)
#  Point(5, -5)
#  Point(8, -8)
#  Point(10, -3)
#  Point(9, 4)
#  Point(4, 2)

# %%
showPoints(Points)

# %%
Graham = convexHullGrahamScan(Points)
# Out:
# 6-element Vector{Any}:
#  Point(-1, -1)
#  Point(-2, 5)
#  Point(7, 6)
#  Point(9, 4)
#  Point(10, -3)
#  Point(8, -8)

# %%
showConvexHull(Graham, Points)

# %% [markdown]
# # Convex Hull Gift Wrapping

# %%
Points = readPoints("giftWrapping.txt")
# Out:
# 100-element Vector{Point}:
#  Point(33, 78)
#  Point(-52, 60)
#  Point(-70, -21)
#  Point(62, -47)
#  Point(85, -11)
#  Point(-76, 11)
#  Point(-84, 63)
#  Point(-9, 39)
#  Point(40, -81)
#  Point(-38, 77)
#  Point(26, -40)
#  Point(33, -44)
#  Point(-5, -54)
#  ⋮
#  Point(56, 41)
#  Point(20, -15)
#  Point(-54, 53)
#  Point(89, 95)
#  Point(5, 11)
#  Point(-4, 55)
#  Point(-58, -35)
#  Point(71, -76)
#  Point(-2, -68)
#  Point(86, -33)
#  Point(-30, -82)
#  Point(-69, 37)

# %%
showPoints(Points)

# %%
GiftWrapping = convexHullGiftWrapping(Points)
# Out:
# 12-element Vector{Any}:
#  Point(-99, -35)
#  Point(-97, -40)
#  Point(-74, -85)
#  Point(-38, -96)
#  Point(94, -99)
#  Point(100, -16)
#  Point(99, 68)
#  Point(89, 95)
#  Point(-40, 97)
#  Point(-70, 97)
#  Point(-84, 63)
#  Point(-97, -1)

# %%
showConvexHull(GiftWrapping, Points)
